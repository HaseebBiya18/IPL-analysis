# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Match.csv")

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69761 entries, 0 to 69760
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          69761 non-null  int64
#  1   inning            69761 non-null  int64
#  2   batting_team      69761 non-null  object
#  3   bowling_team      69761 non-null  object
#  4   over              69761 non-null  int64
#  5   ball              69761 non-null  int64
#  6   batsman           69761 non-null  object
#  7   non_striker       69761 non-null  object
#  8   bowler            69761 non-null  object
#  9   is_super_over     69761 non-null  int64
#  10  wide_runs         69761 non-null  int64
#  11  bye_runs          69761 non-null  int64
#  12  legbye_runs       69761 non-null  int64
#  13  noball_runs       69761 non-null  int64
#  14  penalty_runs      69761 non-null  int64
#  15  batsman_runs      69761 non-null  int64
# ...

# %%
#unique will give unique values of particular column
df["batsman"].unique()
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %%
#total runs made by virat kohli
df[df["batsman"]=="V Kohli"]["batsman_runs"].sum()
# Out:
# 1428

# %%
#find all unique bowlers
df["bowler"].unique()
# Out:
# array(['TS Mills', 'A Choudhary', 'YS Chahal', 'S Aravind', 'SR Watson',
#        'TM Head', 'STR Binny', 'A Nehra', 'B Kumar', 'BCJ Cutting',
#        'Rashid Khan', 'DJ Hooda', 'MC Henriques', 'Bipul Sharma',
#        'AB Dinda', 'DL Chahar', 'BA Stokes', 'Imran Tahir', 'A Zampa',
#        'R Bhatia', 'TG Southee', 'HH Pandya', 'MJ McClenaghan',
#        'JJ Bumrah', 'KH Pandya', 'KA Pollard', 'TA Boult', 'PP Chawla',
#        'SP Narine', 'CR Woakes', 'Kuldeep Yadav', 'YK Pathan', 'P Kumar',
#        'DS Kulkarni', 'MS Gony', 'S Kaushik', 'DR Smith', 'SB Jakati',
#        'Sandeep Sharma', 'MM Sharma', 'AR Patel', 'T Natarajan',
#        'MP Stoinis', 'Swapnil Singh', 'DT Christian', 'RD Chahar',
#        'Z Khan', 'CH Morris', 'PJ Cummins', 'S Nadeem', 'A Mishra',
#        'CR Brathwaite', 'B Stanlake', 'Iqbal Abdulla', 'P Negi',
#        'SK Raina', 'Tejas Baroka', 'Basil Thampi', 'SL Malinga',
#        'Harbhajan Singh', 'AS Rajpoot', 'VR Aaron', 'CJ Anderson',
# ...

# %%
# find extra runs given by  TA Boult
df[df["bowler"]=="TA Boult"]["extra_runs"].sum()
# Out:
# 11

# %%
# total wide runs given by YS Chahal
df[df["bowler"]=="YS Chahal"]["wide_runs"].sum()
# Out:
# 10

# %%
# total super overs bowled by JJ Bumrah
df[df["bowler"]=="JJ Bumrah"]["is_super_over"].sum()
# Out:
# 8

# %%
#find  runs made by batsman
df["batsman_runs"].sum()
# Out:
# 84514

# %%
#find extra runs given by bowler
df["extra_runs"].sum()
# Out:
# 5121

# %%
#find all unique values of fielder column
df["fielder"].unique()
# Out:
# array([nan, 'Mandeep Singh', 'Sachin Baby', 'DA Warner', 'BCJ Cutting',
#        'Yuvraj Singh', 'MC Henriques', 'CJ Jordan (sub)', 'MS Dhoni',
#        'R Bhatia', 'MA Agarwal', 'RG Sharma', 'N Rana', 'TG Southee',
#        'YK Pathan', 'Kuldeep Yadav', 'MP Stoinis', 'M Vohra',
#        'GJ Maxwell', 'MK Tiwary', 'BA Stokes', 'SV Samson', 'RR Pant',
#        'SW Billings', 'S Nadeem', 'CH Morris', 'B Stanlake', 'STR Binny',
#        'S Dhawan', 'V Shankar (sub)', 'NV Ojha', 'Rashid Khan',
#        'BB McCullum', 'MJ McClenaghan', 'HH Pandya', 'KA Pollard',
#        'RV Uthappa', 'R Dhawan (sub)', 'SP Narine', 'WP Saha', 'KK Nair',
#        'A Mishra', 'PA Patel', 'B Kumar', 'G Gambhir', 'MK Pandey',
#        'CR Woakes', 'SA Yadav', 'AR Patel', 'JC Buttler', 'JJ Bumrah',
#        'CH Gayle', 'S Aravind', 'AB de Villiers', 'SK Raina', 'AJ Finch',
#        'Ishan Kishan', 'RD Chahar', 'C de Grandhomme', 'EJG Morgan',
#        'DA Miller', 'MM Sharma', 'Z Khan', 'KH Pandya', 'JJ Roy',
# ...

# %%
# find unique values of dismissal kind 
df["dismissal_kind"].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket'], dtype=object)

# %%
#how many times v kohli got caught (player_dismissed,dismissal_kind)
df[(df["player_dismissed"]=="V Kohli") & (df["dismissal_kind"]=="caught")]
# Out:
#        match_id  inning                 batting_team            bowling_team  \
# 2683         12       1  Royal Challengers Bangalore          Mumbai Indians
# 3975         17       2  Royal Challengers Bangalore  Rising Pune Supergiant
# 4658         20       1  Royal Challengers Bangalore           Gujarat Lions
# 6378         27       2  Royal Challengers Bangalore   Kolkata Knight Riders
# 6945         30       1  Royal Challengers Bangalore           Gujarat Lions
# 7828         33       2  Royal Challengers Bangalore  Rising Pune Supergiant
# 8540         37       1  Royal Challengers Bangalore          Mumbai Indians
# 12849        55       1  Royal Challengers Bangalore        Delhi Daredevils
# 14760        63       2  Royal Challengers Bangalore          Mumbai Indians
# 16299        70       1  Royal Challengers Bangalore        Rajasthan Royals
# 18845        80       2  Royal Challengers Bangalore         Deccan Chargers
# ...

# %%
#find how many cataches are taken by Mandeep Singh 
df[(df["fielder"]=="Mandeep Singh") & (df["dismissal_kind"]=="caught")]
# Out:
#        match_id  inning            batting_team                 bowling_team  \
# 11            1       1     Sunrisers Hyderabad  Royal Challengers Bangalore
# 2728         12       2          Mumbai Indians  Royal Challengers Bangalore
# 3922         17       1  Rising Pune Supergiant  Royal Challengers Bangalore
# 4691         20       2           Gujarat Lions  Royal Challengers Bangalore
# 6355         27       1   Kolkata Knight Riders  Royal Challengers Bangalore
# 9751         42       1         Kings XI Punjab  Royal Challengers Bangalore
# 69340       293       2        Delhi Daredevils              Kings XI Punjab
#
#        over  ball         batsman  non_striker       bowler  is_super_over  \
# 11        2     5       DA Warner     S Dhawan  A Choudhary              0
# 2728      3     3  MJ McClenaghan    RG Sharma     S Badree              0
# 3922     17     5    DT Christian    BA Stokes    S Aravind              0
# ...

# %%
#no of stumpout done MS Dhoni
df[(df["fielder"]=="MS Dhoni") & (df["dismissal_kind"]=="stumped")]
# Out:
#        match_id  inning                 batting_team            bowling_team  \
# 3024         13       2                Gujarat Lions  Rising Pune Supergiant
# 4006         17       2  Royal Challengers Bangalore  Rising Pune Supergiant
# 11944        51       1             Delhi Daredevils  Rising Pune Supergiant
# 28296       122       2  Royal Challengers Bangalore     Chennai Super Kings
# 32944       141       2             Delhi Daredevils     Chennai Super Kings
# 35415       152       1             Rajasthan Royals     Chennai Super Kings
# 35445       152       1             Rajasthan Royals     Chennai Super Kings
# 49905       211       2               Mumbai Indians     Chennai Super Kings
# 51089       216       2              Deccan Chargers     Chennai Super Kings
# 52411       222       1        Kolkata Knight Riders     Chennai Super Kings
# 52422       222       1        Kolkata Knight Riders     Chennai Super Kings
# ...

# %%
# How many sixes scored by CH Gayle ,len will show length that is number of records
len(df[(df["batsman"]=="CH Gayle") & (df["batsman_runs"]==6)])
# Out:
# 72

# %%
# find how many times MS Dhoni got out by YS Chahal
len(df[(df["player_dismissed"]=="MS Dhoni") & (df["bowler"]=="YS Chahal")])
# Out:
# 0

# %%
#who is overall orange cap holder
bnames=df["batsman"].unique()
data={}
for i in bnames:
    single_batsman_run=df[df["batsman"]==i]["batsman_runs"].sum()
    data[i]=single_batsman_run
print(data)
# Out:
# {'DA Warner': 1391, 'S Dhawan': 1355, 'MC Henriques': 326, 'Yuvraj Singh': 1469, 'DJ Hooda': 78, 'BCJ Cutting': 51, 'CH Gayle': 1112, 'Mandeep Singh': 232, 'TM Head': 151, 'KM Jadhav': 360, 'SR Watson': 969, 'Sachin Baby': 15, 'STR Binny': 123, 'S Aravind': 34, 'YS Chahal': 13, 'TS Mills': 8, 'A Choudhary': 25, 'PA Patel': 1107, 'JC Buttler': 273, 'RG Sharma': 1794, 'N Rana': 333, 'AT Rayudu': 811, 'KH Pandya': 243, 'KA Pollard': 770, 'HH Pandya': 250, 'TG Southee': 7, 'AM Rahane': 650, 'MA Agarwal': 82, 'SPD Smith': 472, 'BA Stokes': 316, 'MS Dhoni': 1585, 'JJ Roy': 59, 'BB McCullum': 1232, 'SK Raina': 2159, 'AJ Finch': 368, 'KD Karthik': 1343, 'G Gambhir': 1907, 'CA Lynn': 295, 'MK Tiwary': 970, 'DT Christian': 260, 'HM Amla': 420, 'M Vohra': 229, 'WP Saha': 532, 'AR Patel': 227, 'GJ Maxwell': 310, 'DA Miller': 83, 'Vishnu Vinod': 19, 'Iqbal Abdulla': 21, 'P Negi': 144, 'AP Tare': 68, 'SW Billings': 138, 'KK Nair': 281, 'SV Samson': 386, 'RR Pant': 366, 'CH Morris': 154, 'CR Brathw
# ...

# %%
#mx, bat_mx are functions created to store data . (f {}) is used to 
mx=0
bat_mx=""
for i in data:
    if data[i]>mx:
        mx=data[i]
        bat_mx=i
print(f"batsman name is = {bat_mx} and the runs he scored is {mx}")
# Out:
# batsman name is = SK Raina and the runs he scored is 2159

# %%
#to find total wickets taken by YS Chahal
total_wickets = df[df["bowler"] == "YS Chahal"]["player_dismissed"].dropna().count()
print("Total wickets taken by YS Chahal:", total_wickets)
# Out:
# Total wickets taken by YS Chahal: 14

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Match.csv")
# Calculate total runs per over
total_runs_per_over = df.groupby('over')['total_runs'].sum()
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(total_runs_per_over.index, total_runs_per_over.values, marker='o', linestyle='-')
plt.title('Total Runs per Over')
plt.xlabel('Over')
plt.ylabel('Total Runs')
plt.grid(True)
plt.show()

# %%
#countplot
plt.figure(figsize=(10, 6))
sns.countplot(x='batting_team', data=df)
plt.xticks(rotation=45)
plt.title('Matches by Batting Team')
plt.show()

# %%
#Histogram
plt.hist(df['batsman_runs'])
plt.title('Distribution of Batsman Runs')
plt.xlabel('Runs')
plt.ylabel('Frequency')
plt.show()

# %%
#boxplot
sns.boxplot(x='inning', y='batsman_runs', data=df)
plt.title('Batsman Runs by Inning')
plt.show()

# %%
#Scatter plot
plt.scatter(df['over'], df['batsman_runs'])
plt.title('Batsman Runs by Over')
plt.xlabel('Over')
plt.ylabel('Runs')
plt.show()
